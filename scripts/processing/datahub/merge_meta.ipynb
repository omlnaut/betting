# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from pathlib import Path

from betting.utility import *
from betting.data.cleanup import load_meta

# %% [markdown]
# # Merging datahub data with sportde meta

# %%
hub_dir = Path('../../../data/datahub')
meta_dir = Path('../../../data/sportde/')

# %%
match_meta = pd.read_feather(meta_dir/'games.feather')
standings_meta = pd.read_feather(meta_dir/'standings.feather')

# %%
actual = pd.read_feather(hub_dir/'concat.feather')
actual.head()
# Out:
#         Date     HomeTeam    AwayTeam  FTHG  FTAG  B365H  B365D  B365A  \
# 0 2009-08-15  Aston Villa       Wigan     0     2   1.67   3.60   5.50
# 1 2009-08-15    Blackburn    Man City     0     2   3.60   3.25   2.10
# 2 2009-08-15       Bolton  Sunderland     0     1   2.25   3.25   3.25
# 3 2009-08-15      Chelsea   Hull City     2     1   1.17   6.50  21.00
# 4 2009-08-15      Everton     Arsenal     1     6   3.20   3.25   2.30
#
#    season          league
# 0    2009  premier_league
# 1    2009  premier_league
# 2    2009  premier_league
# 3    2009  premier_league
# 4    2009  premier_league

# %% [markdown]
# ## Leagues, Season

# %%
actual.league.unique()
# Out:
# array(['premier_league', 'league_one', 'bundesliga', 'serie_a',
#        'primera_division'], dtype=object)

# %%
actual.season.unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018])

# %% [markdown]
# ## Matchday

# %%
actual.dtypes
# Out:
# Date        datetime64[ns]
# HomeTeam            object
# AwayTeam            object
# FTHG                 int64
# FTAG                 int64
# B365H              float64
# B365D              float64
# B365A              float64
# season               int32
# league              object
# dtype: object

# %%
match_meta.head()
# Out:
#    season  matchday     home_team      away_team  home_goals  away_goals  \
# 0    2005         1     FC Bayern     M'gladbach           3           0
# 1    2005         1  Hamburger SV       Nürnberg           3           0
# 2    2005         1     1.FC Köln       Mainz 05           1           0
# 3    2005         1      Duisburg  VfB Stuttgart           1           1
# 4    2005         1     Wolfsburg       Dortmund           2           2
#
#        league
# 0  bundesliga
# 1  bundesliga
# 2  bundesliga
# 3  bundesliga
# 4  bundesliga

# %%
with_matchday = pd.merge(actual, match_meta,
                  left_on=['season', 'league', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG'],
                  right_on=['season', 'league', 'home_team', 'away_team', 'home_goals', 'away_goals']
                 )

with_matchday.drop(columns=['FTHG', 'FTAG', 'HomeTeam', 'AwayTeam'], inplace=True)
with_matchday.head()
# Out:
#         Date  B365H  B365D  B365A  season          league  matchday  \
# 0 2009-08-15   1.67   3.60   5.50    2009  premier_league         1
# 1 2009-08-15   3.60   3.25   2.10    2009  premier_league         1
# 2 2009-08-15   2.25   3.25   3.25    2009  premier_league         1
# 3 2009-08-15   1.17   6.50  21.00    2009  premier_league         1
# 4 2009-08-15   3.20   3.25   2.30    2009  premier_league         1
#
#      home_team   away_team  home_goals  away_goals
# 0  Aston Villa       Wigan           0           2
# 1    Blackburn    Man City           0           2
# 2       Bolton  Sunderland           0           1
# 3      Chelsea   Hull City           2           1
# 4      Everton     Arsenal           1           6

# %% [markdown]
# ## Standings

# %% [markdown]
# Shift standings by one matchday so that each row only contains information available at that point.

# %%
standings_meta.matchday += 1

# %%
with_standings = merge_with_prefix(with_matchday, standings_meta, 'home_',
                  left_on=['season', 'league', 'home_team', 'matchday'],
                 right_on=['season', 'league', 'team', 'matchday'],
                                  drop_additional=True)

with_standings = merge_with_prefix(with_standings, standings_meta, 'away_',
                  left_on=['season', 'league', 'away_team', 'matchday'],
                 right_on=['season', 'league', 'team', 'matchday'],
                                  drop_additional=True)

with_standings.head()
# Out:
#         Date  B365H  B365D  B365A  season          league  matchday  \
# 0 2009-08-22   1.17   7.00  19.00    2009  premier_league         3
# 1 2009-08-22   2.30   3.20   3.25    2009  premier_league         3
# 2 2009-08-22   2.60   3.25   2.80    2009  premier_league         3
# 3 2009-08-22   1.33   4.50  12.00    2009  premier_league         3
# 4 2009-08-22   2.10   3.25   3.75    2009  premier_league         3
#
#     home_team      away_team  home_goals  ...  home_total_goals_received  \
# 0     Arsenal     Portsmouth           4  ...                          1
# 1  Birmingham     Stoke City           0  ...                          1
# 2   Hull City         Bolton           1  ...                          2
# 3    Man City  Wolverhampton           1  ...                          0
# 4  Sunderland      Blackburn           2  ...                          0
#
#    home_points  away_rank  away_games_played  away_wins  away_draw  away_lost  \
# 0            3         20                  1          0          0          1
# 1            0          2                  1          1          0          0
# 2            0         13                  1          0          0          1
# 3            3         15                  1          0          0          1
# 4            3         15                  1          0          0          1
#
#    away_total_goals_scored  away_total_goals_received  away_points
# 0                        0                          1           -9
# 1                        2                          0            3
# 2                        0                          1            0
# 3                        0                          2            0
# 4                        0                          2            0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Column names

# %%
with_standings.rename(columns={'B365H': 'home_odds',
                       'B365D': 'draw_odds',
                       'B365A': 'away_odds'}, inplace=True)
with_standings.head()
# Out:
#         Date  home_odds  draw_odds  away_odds  season          league  \
# 0 2009-08-22       1.17       7.00      19.00    2009  premier_league
# 1 2009-08-22       2.30       3.20       3.25    2009  premier_league
# 2 2009-08-22       2.60       3.25       2.80    2009  premier_league
# 3 2009-08-22       1.33       4.50      12.00    2009  premier_league
# 4 2009-08-22       2.10       3.25       3.75    2009  premier_league
#
#    matchday   home_team      away_team  home_goals  ...  \
# 0         3     Arsenal     Portsmouth           4  ...
# 1         3  Birmingham     Stoke City           0  ...
# 2         3   Hull City         Bolton           1  ...
# 3         3    Man City  Wolverhampton           1  ...
# 4         3  Sunderland      Blackburn           2  ...
#
#    home_total_goals_received  home_points  away_rank  away_games_played  \
# 0                          1            3         20                  1
# 1                          1            0          2                  1
# 2                          2            0         13                  1
# 3                          0            3         15                  1
# 4                          0            3         15                  1
#
#    away_wins  away_draw  away_lost  away_total_goals_scored  \
# 0          0          0          1                        0
# 1          1          0          0                        2
# 2          0          0          1                        0
# 3          0          0          1                        0
# 4          0          0          1                        0
#
#    away_total_goals_received  away_points
# 0                          1           -9
# 1                          0            3
# 2                          1            0
# 3                          2            0
# 4                          2            0
#
# [5 rows x 27 columns]

# %%
with_standings.to_feather(hub_dir/'with_meta.feather')
